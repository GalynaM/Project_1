# %% [markdown]
# ----------------------------------------------------------------------------------------
#
#
# # How Brazil was affected by Hosting the 2016 Summer Olympics
# ----------------------------------------------------------------------------------------
#
#
# ### How hosting the Olympics impacted number of total medals and gold medals Brazil won that year.
#
# #### Assumption
#
# * We assume that Athletes of hosting country will have more familiarity with home field, receive great support from home crowd, have easier qualification criteria, thus more participation is expected.
# * Considering all these factors we are expecting increase in number of Medals Brazil won in Rio 2016 comparing to the number of medals Brazil usually wins.
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ### Data Source
#
# * Historical dataset on the modern Olympic Games, including all the Games from Athens 1896 to Rio 2016 was used.
#  - This dataset was scraped from www.sports-reference.com in May 2018.
#  - https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results?select=noc_regions.csv
#  - The file athlete_events.csv contains 271116 rows and 15 columns. Each row corresponds to an individual athlete   competing in an individual Olympic event (athlete-events).
#
# * World Bank's data API was used to get GDP data.
#  - WBGAPI python package to work with data was installed and used.
#  - https://pypi.org/project/wbgapi/
#  - pip install wbgapi

# %%
pip install wbgapi
# Out:
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# Collecting wbgapi
#   Downloading wbgapi-1.0.12-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from wbgapi) (2.32.2)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.12/site-packages (from wbgapi) (6.0.1)
# Requirement already satisfied: tabulate in /opt/anaconda3/lib/python3.12/site-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->wbgapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->wbgapi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->wbgapi) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->wbgapi) (2024.8.30)
# Downloading wbgapi-1.0.12-py3-none-any.whl (36 kB)
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: wbgapi
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# Successfully installed wbgapi-1.0.12
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.12/site-packages/gmaps-0.9.0.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import wbgapi as wb
from scipy.stats import linregress

# %% [markdown]
# ### Get the Data
# * Load data from csv file
# * Clean data: remove NaN values, remove duplicates

# %%
# Load data about all the athletes/events through the history of Olympics games
path = "../Resources/athlete_events.csv"
all_olymp = pd.read_csv(path)

# %%
# Create Data Frame for Brazil team 
brazil_all = all_olymp.loc[(all_olymp["Team"]=="Brazil")|(all_olymp["Team"]=="Brazil-1")]
brazil_all
# Out:
#             ID                        Name Sex   Age  Height  Weight    Team  \
# 665        386             Alexandre Abeid   M  22.0   194.0    92.0  Brazil
# 666        386             Alexandre Abeid   M  26.0   194.0    92.0  Brazil
# 668        388  Abel Carlos da Silva Braga   M  19.0   190.0    73.0  Brazil
# 781        451         Diana Monteiro Abla   F  21.0   175.0    75.0  Brazil
# 1005       565        Glauclio Serro Abreu   M  26.0   185.0    75.0  Brazil
# ...        ...                         ...  ..   ...     ...     ...     ...
# 268652  134400   Maria Jos "Zz" Bertolotti   F  26.0   190.0     NaN  Brazil
# 269745  134976       Sieglinda Lenk Zigler   F  17.0     NaN     NaN  Brazil
# 269899  135037           Moacir Zimmermann   M  32.0   184.0    70.0  Brazil
# 270478  135289        Zzimo Alves Calazans   M  20.0     NaN     NaN  Brazil
# 270789  135423        Ral Benedito Zumbano   M  22.0     NaN     NaN  Brazil
#
#         NOC        Games  Year  Season            City       Sport  \
# 665     BRA  1972 Summer  1972  Summer          Munich  Volleyball
# 666     BRA  1976 Summer  1976  Summer        Montreal  Volleyball
# 668     BRA  1972 Summer  1972  Summer          Munich    Football
# 781     BRA  2016 Summer  2016  Summer  Rio de Janeiro  Water Polo
# 1005    BRA  2004 Summer  2004  Summer          Athina      Boxing
# ...     ...          ...   ...     ...             ...         ...
# 268652  BRA  1992 Summer  1992  Summer       Barcelona  Basketball
# 269745  BRA  1936 Summer  1936  Summer          Berlin    Swimming
# 269899  BRA  2016 Summer  2016  Summer  Rio de Janeiro   Athletics
# 270478  BRA  1952 Summer  1952  Summer        Helsinki    Football
# 270789  BRA  1948 Summer  1948  Summer          London      Boxing
#
#                                          Event Medal
# 665                Volleyball Men's Volleyball   NaN
# 666                Volleyball Men's Volleyball   NaN
# 668                    Football Men's Football   NaN
# 781              Water Polo Women's Water Polo   NaN
# 1005                 Boxing Men's Middleweight   NaN
# ...                                        ...   ...
# 268652           Basketball Women's Basketball   NaN
# 269745  Swimming Women's 100 metres Backstroke   NaN
# 269899      Athletics Men's 20 kilometres Walk   NaN
# 270478                 Football Men's Football   NaN
# 270789                Boxing Men's Lightweight   NaN
#
# [3800 rows x 15 columns]

# %% [markdown]
# #### Clean data
# #### Drop rows with NaN values to calculate the number of medals Brazil won

# %%
bra_athlets_medal = brazil_all.dropna(subset=['Name', 'Medal'])
bra_athlets_medal
# Out:
#             ID                                          Name Sex   Age  \
# 1651       918                           Ademir Roque Kaefer   M  24.0
# 1652       918                           Ademir Roque Kaefer   M  28.0
# 1668       925           Adenzia Aparecida Ferreira da Silva   F  25.0
# 1733       966                                  Daniel Adler   M  26.0
# 1856      1020                  Adriana Aparecida dos Santos   F  25.0
# ...        ...                                           ...  ..   ...
# 267709  133931                      Arthur Nabarrete Zanetti   M  26.0
# 268211  134186              Jos Elias "Z Elias" Moedim Jnior   M  19.0
# 268218  134190  Jos Marco "Z Marco" Nobrega Ferreira de Melo   M  29.0
# 268219  134191                Jos Marcelo "Z Maria" Ferreira   M  22.0
# 268247  134211                        Jos Carlos Cracco Neto   M  22.0
#
#         Height  Weight      Team  NOC        Games  Year  Season  \
# 1651     179.0    74.0    Brazil  BRA  1984 Summer  1984  Summer
# 1652     179.0    74.0    Brazil  BRA  1988 Summer  1988  Summer
# 1668     187.0    65.0    Brazil  BRA  2012 Summer  2012  Summer
# 1733     180.0    72.0    Brazil  BRA  1984 Summer  1984  Summer
# 1856     180.0    61.0    Brazil  BRA  1996 Summer  1996  Summer
# ...        ...     ...       ...  ...          ...   ...     ...
# 267709   156.0    61.0    Brazil  BRA  2016 Summer  2016  Summer
# 268211   178.0    75.0    Brazil  BRA  1996 Summer  1996  Summer
# 268218   190.0    86.0  Brazil-1  BRA  2000 Summer  2000  Summer
# 268219   175.0    71.0    Brazil  BRA  1996 Summer  1996  Summer
# 268247   170.0    69.0    Brazil  BRA  2016 Summer  2016  Summer
#
#                   City             Sport  \
# 1651       Los Angeles          Football
# 1652             Seoul          Football
# 1668            London        Volleyball
# 1733       Los Angeles           Sailing
# 1856           Atlanta        Basketball
# ...                ...               ...
# 267709  Rio de Janeiro        Gymnastics
# 268211         Atlanta          Football
# 268218          Sydney  Beach Volleyball
# 268219         Atlanta          Football
# 268247  Rio de Janeiro          Football
#
#                                           Event   Medal
# 1651                    Football Men's Football  Silver
# 1652                    Football Men's Football  Silver
# 1668              Volleyball Women's Volleyball    Gold
# 1733        Sailing Mixed Three Person Keelboat  Silver
# 1856              Basketball Women's Basketball  Silver
# ...                                         ...     ...
# 267709                   Gymnastics Men's Rings  Silver
# 268211                  Football Men's Football  Bronze
# 268218  Beach Volleyball Men's Beach Volleyball  Silver
# 268219                  Football Men's Football  Bronze
# 268247                  Football Men's Football    Gold
#
# [469 rows x 15 columns]

# %%
#bra_athlets_medal = brazil_all.dropna(inplace = False)
#bra_athlets_medal
# Out:
#             ID                                          Name Sex   Age  \
# 1651       918                           Ademir Roque Kaefer   M  24.0
# 1652       918                           Ademir Roque Kaefer   M  28.0
# 1668       925           Adenzia Aparecida Ferreira da Silva   F  25.0
# 1733       966                                  Daniel Adler   M  26.0
# 1856      1020                  Adriana Aparecida dos Santos   F  25.0
# ...        ...                                           ...  ..   ...
# 267709  133931                      Arthur Nabarrete Zanetti   M  26.0
# 268211  134186              Jos Elias "Z Elias" Moedim Jnior   M  19.0
# 268218  134190  Jos Marco "Z Marco" Nobrega Ferreira de Melo   M  29.0
# 268219  134191                Jos Marcelo "Z Maria" Ferreira   M  22.0
# 268247  134211                        Jos Carlos Cracco Neto   M  22.0
#
#         Height  Weight      Team  NOC        Games  Year  Season  \
# 1651     179.0    74.0    Brazil  BRA  1984 Summer  1984  Summer
# 1652     179.0    74.0    Brazil  BRA  1988 Summer  1988  Summer
# 1668     187.0    65.0    Brazil  BRA  2012 Summer  2012  Summer
# 1733     180.0    72.0    Brazil  BRA  1984 Summer  1984  Summer
# 1856     180.0    61.0    Brazil  BRA  1996 Summer  1996  Summer
# ...        ...     ...       ...  ...          ...   ...     ...
# 267709   156.0    61.0    Brazil  BRA  2016 Summer  2016  Summer
# 268211   178.0    75.0    Brazil  BRA  1996 Summer  1996  Summer
# 268218   190.0    86.0  Brazil-1  BRA  2000 Summer  2000  Summer
# 268219   175.0    71.0    Brazil  BRA  1996 Summer  1996  Summer
# 268247   170.0    69.0    Brazil  BRA  2016 Summer  2016  Summer
#
#                   City             Sport  \
# 1651       Los Angeles          Football
# 1652             Seoul          Football
# 1668            London        Volleyball
# 1733       Los Angeles           Sailing
# 1856           Atlanta        Basketball
# ...                ...               ...
# 267709  Rio de Janeiro        Gymnastics
# 268211         Atlanta          Football
# 268218          Sydney  Beach Volleyball
# 268219         Atlanta          Football
# 268247  Rio de Janeiro          Football
#
#                                           Event   Medal
# 1651                    Football Men's Football  Silver
# 1652                    Football Men's Football  Silver
# 1668              Volleyball Women's Volleyball    Gold
# 1733        Sailing Mixed Three Person Keelboat  Silver
# 1856              Basketball Women's Basketball  Silver
# ...                                         ...     ...
# 267709                   Gymnastics Men's Rings  Silver
# 268211                  Football Men's Football  Bronze
# 268218  Beach Volleyball Men's Beach Volleyball  Silver
# 268219                  Football Men's Football  Bronze
# 268247                  Football Men's Football    Gold
#
# [442 rows x 15 columns]

# %% [markdown]
# #### Search for duplicates, include Athlet ID, Games, Event and Medal

# %%
medal_duplicates = bra_athlets_medal.loc[bra_athlets_medal.duplicated(subset = ["ID", "Games", "Medal", "Event"])]
medal_duplicates
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %% [markdown]
# #### Create DataFrame with medals for Brazil
# * Initial data set includes all medals for all athletes
# * We need to exlude medals that athlets win in the same event
# * E.g. for such events as "Football Men's Football" the whole team gets medals, but for Brazil it is only one medal

# %%
# Get Names of Group Events with duplicated medals

# Get years Brazil participated in Olympics
years = bra_athlets_medal["Year"].unique()

# Create List to store Names of Group Events
group_events = []

# Iterate bra_athlets_medal DataFrame by years
for year in years:
    
    df = bra_athlets_medal.loc[(bra_athlets_medal["Year"]==year)]
    
    # For each year find duplicates in Event, Medal columns, get Group Names from Event column
    values = df.loc[df.duplicated(subset = ["Event", "Medal"])]["Event"].unique()
    
    # Add found unique Group Names to group_events    
    for val in values:
        if val not in group_events:
            group_events.append(val)
            
group_events
# Out:
# ["Football Men's Football",
#  "Volleyball Men's Volleyball",
#  'Sailing Mixed Three Person Keelboat',
#  'Sailing Mixed Multihull',
#  'Sailing Mixed Two Person Keelboat',
#  "Beach Volleyball Men's Beach Volleyball",
#  "Volleyball Women's Volleyball",
#  "Beach Volleyball Women's Beach Volleyball",
#  "Sailing Men's Two Person Keelboat",
#  "Basketball Women's Basketball",
#  "Athletics Men's 4 x 100 metres Relay",
#  'Equestrianism Mixed Jumping, Team',
#  "Swimming Men's 4 x 100 metres Freestyle Relay",
#  "Football Women's Football",
#  "Sailing Women's Two Person Dinghy",
#  "Basketball Men's Basketball",
#  "Sailing Women's Skiff",
#  "Canoeing Men's Canadian Doubles, 1,000 metres",
#  "Shooting Men's Free Pistol, 50 metres, Team",
#  "Swimming Men's 4 x 200 metres Freestyle Relay",
#  'Sailing Mixed Two Person Dinghy',
#  'Sailing Mixed Two Person Heavyweight Dinghy']

# %%
# Store indices of found duplicated medals
indices = []

# Iterate over Data Frame to locate indices of the duplicated medals
# By duplicated here we mean medal for a group event like "Volleyball Men's Volleyball"

# For each year
for year in years:
   
    # Find duplicated medals for each event in group_events    
    for event in group_events:
        
        all_index = bra_athlets_medal.loc[
            (bra_athlets_medal["Year"]==year)&(bra_athlets_medal["Event"]==event)].index
        
        # If such medals are found store the indices of rows except the first one to keep the medal for Brazil        
        if len(all_index)>0:
            
            for i in range(1, len(all_index)):
                
                indices.append(all_index[i])

# Drop rows with duplicated medals                
brazil_medals = bra_athlets_medal.drop(indices, inplace=False)

# Save Brazil medals to .csv
brazil_medals.to_csv("Output/BRA_medals.csv")
brazil_medals
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1651       918                  Ademir Roque Kaefer   M  24.0   179.0    74.0
# 1652       918                  Ademir Roque Kaefer   M  28.0   179.0    74.0
# 1668       925  Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
# 1733       966                         Daniel Adler   M  26.0   180.0    72.0
# 1856      1020         Adriana Aparecida dos Santos   F  25.0   180.0    61.0
# ...        ...                                  ...  ..   ...     ...     ...
# 221565  111358           Maicon de Andrade Siqueira   M  23.0   190.0    90.0
# 252454  126422               Douglas Eduardo Vieira   M  24.0   170.0    95.0
# 263339  131784                    Felipe Almeida Wu   M  24.0   169.0    69.0
# 267707  133931             Arthur Nabarrete Zanetti   M  22.0   156.0    61.0
# 267709  133931             Arthur Nabarrete Zanetti   M  26.0   156.0    61.0
#
#           Team  NOC        Games  Year  Season            City       Sport  \
# 1651    Brazil  BRA  1984 Summer  1984  Summer     Los Angeles    Football
# 1652    Brazil  BRA  1988 Summer  1988  Summer           Seoul    Football
# 1668    Brazil  BRA  2012 Summer  2012  Summer          London  Volleyball
# 1733    Brazil  BRA  1984 Summer  1984  Summer     Los Angeles     Sailing
# 1856    Brazil  BRA  1996 Summer  1996  Summer         Atlanta  Basketball
# ...        ...  ...          ...   ...     ...             ...         ...
# 221565  Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro   Taekwondo
# 252454  Brazil  BRA  1984 Summer  1984  Summer     Los Angeles        Judo
# 263339  Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro    Shooting
# 267707  Brazil  BRA  2012 Summer  2012  Summer          London  Gymnastics
# 267709  Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                        Event   Medal
# 1651                 Football Men's Football  Silver
# 1652                 Football Men's Football  Silver
# 1668           Volleyball Women's Volleyball    Gold
# 1733     Sailing Mixed Three Person Keelboat  Silver
# 1856           Basketball Women's Basketball  Silver
# ...                                      ...     ...
# 221565           Taekwondo Men's Heavyweight  Bronze
# 252454           Judo Men's Half-Heavyweight  Silver
# 263339  Shooting Men's Air Pistol, 10 metres  Silver
# 267707                Gymnastics Men's Rings    Gold
# 267709                Gymnastics Men's Rings  Silver
#
# [125 rows x 15 columns]

# %%
# Test DataFrame after drop
check = brazil_medals.loc[(brazil_medals["Year"]==2016)].sort_values(by='Event')
check
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 28565    14810                Thiago Braz da Silva   M  22.0   183.0    75.0
# 4825      2758                Alison Conte Cerutti   M  30.0   203.0   106.0
# 14312     7716            Brbara Seixas de Freitas   F  29.0   178.0    67.0
# 43889    22623               Robson Donato Conceio   M  27.0   171.0    57.0
# 194969   97845         Isaquias Queiroz dos Santos   M  22.0   175.0    85.0
# 194968   97845         Isaquias Queiroz dos Santos   M  22.0   175.0    85.0
# 194967   97845         Isaquias Queiroz dos Santos   M  22.0   175.0    85.0
# 58064    29713  Douglas dos Santos Justino de Melo   M  22.0   173.0    69.0
# 149540   75010         Arthur Nory Oyakawa Mariano   M  22.0   169.0    65.0
# 101753   51457                Diego Matias Hyplito   M  30.0   170.0    68.0
# 267709  133931            Arthur Nabarrete Zanetti   M  26.0   156.0    61.0
# 47985    24730              Rafael Carlos da Silva   M  29.0   203.0   160.0
# 47976    24724               Mayra Aguiar da Silva   F  25.0   177.0    78.0
# 220065  110549                 Rafaela Lopes Silva   F  24.0   169.0    57.0
# 83124    42228             Martine Soffiatti Grael   F  25.0   168.0    62.0
# 263339  131784                   Felipe Almeida Wu   M  24.0   169.0    69.0
# 175986   88461              Poliana Okimoto-Cintra   F  33.0   165.0    52.0
# 221565  111358          Maicon de Andrade Siqueira   M  23.0   190.0    90.0
# 9260      5093              William Peixoto Arjona   M  37.0   186.0    78.0
#
#             Team  NOC        Games  Year  Season            City  \
# 28565     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 4825    Brazil-1  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 14312   Brazil-1  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 43889     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 194969    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 194968    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 194967    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 58064     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 149540    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 101753    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 267709    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 47985     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 47976     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 220065    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 83124     Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 263339    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 175986    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 221565    Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
# 9260      Brazil  BRA  2016 Summer  2016  Summer  Rio de Janeiro
#
#                    Sport                                          Event  \
# 28565          Athletics                     Athletics Men's Pole Vault
# 4825    Beach Volleyball        Beach Volleyball Men's Beach Volleyball
# 14312   Beach Volleyball      Beach Volleyball Women's Beach Volleyball
# 43889             Boxing                       Boxing Men's Lightweight
# 194969          Canoeing  Canoeing Men's Canadian Doubles, 1,000 metres
# 194968          Canoeing  Canoeing Men's Canadian Singles, 1,000 metres
# 194967          Canoeing    Canoeing Men's Canadian Singles, 200 metres
# 58064           Football                        Football Men's Football
# 149540        Gymnastics                Gymnastics Men's Floor Exercise
# 101753        Gymnastics                Gymnastics Men's Floor Exercise
# 267709        Gymnastics                         Gymnastics Men's Rings
# 47985               Judo                         Judo Men's Heavyweight
# 47976               Judo                  Judo Women's Half-Heavyweight
# 220065              Judo                       Judo Women's Lightweight
# 83124            Sailing                          Sailing Women's Skiff
# 263339          Shooting           Shooting Men's Air Pistol, 10 metres
# 175986          Swimming      Swimming Women's 10 kilometres Open Water
# 221565         Taekwondo                    Taekwondo Men's Heavyweight
# 9260          Volleyball                    Volleyball Men's Volleyball
#
#          Medal
# 28565     Gold
# 4825      Gold
# 14312   Silver
# 43889     Gold
# 194969  Silver
# 194968  Silver
# 194967  Bronze
# 58064     Gold
# 149540  Bronze
# 101753  Silver
# 267709  Silver
# 47985   Bronze
# 47976   Bronze
# 220065    Gold
# 83124     Gold
# 263339  Silver
# 175986  Bronze
# 221565  Bronze
# 9260      Gold

# %% [markdown]
# ### Investigate how the hosting of Rio 2016 affected the number of medals Brazil won.
# * Calculate the number of total Medals Brazil won in each year the country participated in Olympics
# * Calculate the number of Gold Medals Brazil won in each year the country participated in Olympics
# * Compare Medals count in the hosting year to the previous years

# %% [markdown]
# ### Bar Chart
# #### Total Medals Brazil won in Olympics

# %%
# Calculate the number of total Medals over years
total_medals = brazil_medals.groupby("Year")["Medal"].count()

fig,ax = plt.subplots()

medals_plot = total_medals.plot(kind = "bar", figsize=(12,6), width = 0.8, color="teal", alpha = 0.8,
                             title = "Total number of Medals Brazil won throughout the History of Olympics",
                                grid = True, ax = ax, label = "Medals count")
medals_plot.set_ylabel("Number of Total Medals")
medals_plot.set_xlabel("Y e a r s")

plt.yticks(np.arange(0, 20, 1))

ax.axvline(total_medals.index.searchsorted('2016'), color="orange", linestyle="--", lw=4,
           alpha = .7, label="Hosting Year")

plt.legend()
plt.tight_layout()

fig.savefig(f"Output/BRA_Total_medals.png")

# %% [markdown]
# ### Find average number of Medals Brazil usually wins

# %%
aver96_12 = total_medals.loc[total_medals.index>=1996].mean()
print(f"Average number of Medals in 1996-2012: {round(aver96_12,2)}")
aver_less96 = total_medals.loc[total_medals.index<1996].mean()
print(f"Average number of Medals before 1996: {aver_less96}")
# Out:
# Average number of Medals in 1996-2012: 14.33
# Average number of Medals before 1996: 3.0

# %% [markdown]
# #### Gold Medals Brazil won in Olympics

# %%
# Calculate the number of Gold Medals over years
gold_medals = brazil_medals.loc[brazil_medals["Medal"]=="Gold"].groupby("Year")["Medal"].count()

figG,ax = plt.subplots()

gold_plot = gold_medals.plot(kind = "bar", figsize=(12,6),
                             width = 0.6, color="teal", alpha = 0.8, grid = True,
                             title = "Total number of Gold Medals Brazil won in the History of Olympics")
gold_plot.set_ylabel("Number of Gold Medals")
gold_plot.set_xlabel("Y e a r s")

ax.axvline(gold_medals.index.searchsorted('2016'), color="orange", linestyle="--", lw=4,
           alpha = .7, label="Hosting Year")

plt.legend()
plt.tight_layout()

figG.savefig(f"Output/BRA_Gold_medals.png")

# %% [markdown]
# ### Investigate GDP measure
# * A possible factor of increasing medal count could be the increase of GDP (or GDP per capita).
# * Get GDP per capita Data for years corresponding the Olympics.
# * Build Linear Regression Model to see if there is a correlation between Medal Count and GDP.

# %%
# Get GDP per capita
#wb.series.info('NY.GDP.PCAP.CD')
#BRA_gdp = wb.data.DataFrame(['NY.GDP.PCAP.CD', 'SP.POP.TOTL'], 'BRA', range(1980, 2020, 4))
#BRA_gdp

# %%
# Get GDP per capita
wb.series.info('NY.GDP.PCAP.CD')
BRA_gdp = wb.data.DataFrame(['NY.GDP.PCAP.CD'], 'BRA', range(1980, 2020, 4))
BRA_gdp
# Out:
#          YR1980  YR1984  YR1988       YR1992       YR1996       YR2000  \
# economy
# BRA         NaN     NaN     NaN  2105.133078  5121.905407  3726.811669
#
#               YR2004       YR2008        YR2012       YR2016
# economy
# BRA      3623.224462  8801.757876  12327.513101  8680.736469

# %%
# Drop those years for which there is no data
BRA_gdp = BRA_gdp.dropna(axis='columns')
BRA_gdp
# Out:
#               YR1992       YR1996       YR2000       YR2004       YR2008  \
# economy
# BRA      2105.133078  5121.905407  3726.811669  3623.224462  8801.757876
#
#                YR2012       YR2016
# economy
# BRA      12327.513101  8680.736469

# %%
# Define what is the first available year with data
f_y = BRA_gdp.columns[0]

# Leave only numbers
first_year = int(f_y[2:6])
first_year
# Out:
# 1992

# %%
years_till_16_row = brazil_medals.loc[brazil_medals["Year"]>=first_year]["Year"].unique()
years_till_16 = sorted(years_till_16_row)
years_till_16
# Out:
# [1992, 1996, 2000, 2004, 2008, 2012, 2016]

# %%
# Get medals
medals_to_16 = brazil_medals.loc[brazil_medals["Year"]>=first_year].groupby("Year")["Medal"].count()
medals_to_16
# Out:
# Year
# 1992     3
# 1996    14
# 2000    11
# 2004    10
# 2008    15
# 2012    17
# 2016    19
# Name: Medal, dtype: int64

# %%
# Get GDPs
col_names = BRA_gdp.columns
col_names
# Out:
# Index(['YR1992', 'YR1996', 'YR2000', 'YR2004', 'YR2008', 'YR2012', 'YR2016'], dtype='object')

# %%
# Create DataFrame
medals_GDP_df = pd.DataFrame({
    "GDPs": BRA_gdp.loc["BRA"].values,
    "Medals": medals_to_16.values
}, index = years_till_16)
medals_GDP_df
# Out:
#               GDPs  Medals
# 1992   2105.133078       3
# 1996   5121.905407      14
# 2000   3726.811669      11
# 2004   3623.224462      10
# 2008   8801.757876      15
# 2012  12327.513101      17
# 2016   8680.736469      19

# %%
# Old version
# Create DataFrame for Total Medals/GDP over available years - starting from 1980
# Get years
#years_80_16_row = brazil_medals.loc[brazil_medals["Year"]>=1980]["Year"].unique()
#years_80_16 = sorted(years_80_16_row)

# Get medals
#medals80_16 = brazil_medals.loc[brazil_medals["Year"]>=1980].groupby("Year")["Medal"].count()
#medals80_16

# Get GDPs
#col_names = BRA_gdp.columns

# Rename columns in GDP df
#allGDP = BRA_gdp.rename(columns={col_names[i]:years_80_16[i] for i in range(len(years_80_16))})
#allGDP

# Create DataFrame
#medals_GDP_df = pd.DataFrame({
#    "GDPs": allGDP.loc["NY.GDP.PCAP.CD"],
#    "Medals": medals80_16
#}, index = years_80_16)
#medals_GDP_df

# %%
# Plot scatter chart for Total medals vs GDP per capita, set weights as number of Medals

# Define size of markers
s = [60*n for n in medals_GDP_df.Medals]
s

# Set Parameters for scatter plot
figS, ax = plt.subplots()
figS.set_size_inches(13, 7)

scatter_plot = medals_GDP_df.plot(kind = 'scatter', x = "GDPs", y = "Medals", grid=True,
                   s = s, marker="o", c="red", alpha = .5, edgecolors="black",
                   title="Medal Count vs GDP per capita", ax=ax)

scatter_plot.set_xlabel("Gross Domestic Product per Capita ($)")
scatter_plot.set_ylabel("Medal Count")
scatter_plot.set_ylim(0.5,20)
scatter_plot.set_xlim(1000,13000)

for k, v in medals_GDP_df.iterrows():
    ax.annotate(f"      {k}", v)

plt.tight_layout()

figS.savefig(f"Output/Medals_vs_GDP.png")

# %%
# Build linear regression model to find if there is a correlation btw Medal Count and GDP

x_values = medals_GDP_df.GDPs
y_values = medals_GDP_df.Medals

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Plot linear regression with scatter plot
plt.figure(figsize=(12,6))
plt.scatter(x_values,y_values, marker="o", s = [v/4 for v in s], c="blue", alpha = .5, edgecolors="black")
plt.plot(x_values,regress_values,"r-")

plt.title("Linear Regression Model for Medal Count vs GDP")
plt.xlabel("GDP per Capita ($)")
plt.ylabel("Medal Count")

print(f"R-value is {rvalue}")

plt.tight_layout()

plt.savefig(f"Output/Lin_regress_Medals_vs_GDP.png")
# Out:
# R-value is 0.8315703532201106

# %% [markdown]
# ### Analysis
# * Data for Total Number of Medals and Number of Gold Medals Brazil won in each Olympics was obtained and investigated.
# * Bar Charts for Total number of Medals and Total number of Gold Medals over olympics years shows:
#  - Hosting Year 2016:
#     * Total number of Medals is higher than in any other previous games: 19 medals total.
#      - The average for years with highest Medal Count (1996-2012) is 14.3;
#      - The average for all other years (<1996) is 2.75 total medals.
#     * Total number of Gold Medals is higher than in any other previous games: 7 gold medals.
#      - The next highest number is 5 Gold Medals in 2004;
#      - For all other games the average number is 1.7 gold medals.
# * GDP per capita data was obtained for Olympics years to investigate if there is a correlation between Medal Count and GDP per capita.
#  - Scatter Chart for Total Medals vs GDP per capita for Olympics years was plotted. Weights are the Medal Counts.
#  - Linear Regression Model was calculated and plotted for those values.
#  - Found R-value = 0.85 shows that there is a strong correlation between GDP per capita and Medals Count.
#  - However, the hosting year does not have the highest GDP (8710.097), but the Medal number is the highest (19).
#
# #### Conclusion
# * The obtained during analysis data shows that in the hosting year 2016 Brazil won its highest number of medals comparing to previous years. This is true for total number of medals as well as for number of gold medals.
# * We investigated Brazil GDP over Olympics years to see if number of medals country wins could be explained by country's GDP.
# * We found strong correlation between Number of Medals and GDP per capita with R-value = 0.85.
# * However, GDP itself can not explain the raise in Number of Medals in 2016.
# * So we can conclude that our assumption was correct and it's hosting of the Olympics that caused Brazil to win more medals this year.
